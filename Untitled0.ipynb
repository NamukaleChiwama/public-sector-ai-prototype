# %% [markdown]
# <a href="https://colab.research.google.com/github/NamukaleChiwama/public-sector-ai-prototype/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install unsloth trl peft bitsandbytes datasets
# Out:
# ...
#   Using cached unsloth-2026.9.9-py3-none-any.whl.metadata (83 kB)
# ...
#   Using cached trl-1.13.0-py3-none-any.whl.metadata (12 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.3/24.3 MB 64.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 38.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.1/43.1 MB 22.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 46.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 14.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 kB 23.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.7/146.7 kB 18.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.8/73.8 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 111.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 95.5 MB/s eta 0:00:00
# ...

# %%
# !pip install unsloth trl peft bitsandbytes datasets

# %%
import json
#Define sample public sector intruction data
dataset_data =[
    {
        "instruction": "Categorize and summerize thispublic request: 'The streetlights along Great East Road near UNZA have beeen out for three days and it feels unsafe at night.'",
        "output": "Category :Infrastructure & Public safety | Priority:High | Summary: Streetlight outrage reported along Great East Road near UNZA."

    },
    {
         "instruction": "Categorize and summarize this public request: 'How do I apply for a business operating permit or update my business registrationin Lusaka?'",
         "output" : "Category Administrative Services | Priority: Medium| Summary:inquiry regarding business operating permit applicationand registration updates in Lusaka."
    },
    {
        "instruction": "Categorize and summarize this public request: 'There is a major water pipe leak floading the road near the market area.'",
        "output": "Category: Utilities $ Water Supply | Priority:High | Summary: Major water pipe leak and flooding near market area."

    }
]

# Save the dataset locally as a JSON file with open("public_sector_dataset. json", "w") as f:json.dump(dataset_data, f, indent=2)

print("Dataset created and saved succcessfully as public_section_dataset.json!")
# Out:
# Dataset created and saved succcessfully as public_section_dataset.json!
